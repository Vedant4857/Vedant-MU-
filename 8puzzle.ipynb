# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedant4857/Vedant-MU-/blob/main/8puzzle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque
import numpy as np

# Define goal state
goal = [[1, 2, 3], [4, 5, 6], [7, 8, 0]]

def get_blank_position(state):
    for i in range(3):
        for j in range(3):
            if state[i][j] == 0:
                return (i, j)

def get_neighbours(state):
    neighbours = []
    blank_i, blank_j = get_blank_position(state)
    for di, dj in [(-1, 0), (1, 0), (0, -1), (0, 1)]:
        new_i, new_j = blank_i + di, blank_j + dj
        if 0 <= new_i < 3 and 0 <= new_j < 3:
            new_state = [row.copy() for row in state]
            new_state[blank_i][blank_j], new_state[new_i][new_j] = new_state[new_i][new_j], new_state[blank_i][blank_j]
            neighbours.append(new_state)
    return neighbours

def solve_8puzzle(initial_state):
    queue = deque([(initial_state, [initial_state])])
    visited = set()
    while queue:
        current, path = queue.popleft()
        visited.add(tuple(map(tuple, current)))
        if current == goal:
            return path
        for neighbour in get_neighbours(current):
            if tuple(map(tuple, neighbour)) not in visited:
                queue.append((neighbour, path + [neighbour]))
    return None

# Example usage
initial = [[1, 3, 2], [4, 6, 5], [0, 7, 8]]
solution = solve_8puzzle(initial)
if solution:
    for step, state in enumerate(solution):
        print(f"Step {step}:")
        for row in state:
            print(row)
else:
    print("No solution found!")
# Out:
# Step 0:
# [1, 3, 2]
# [4, 6, 5]
# [0, 7, 8]
# Step 1:
# [1, 3, 2]
# [0, 6, 5]
# [4, 7, 8]
# Step 2:
# [0, 3, 2]
# [1, 6, 5]
# [4, 7, 8]
# Step 3:
# [3, 0, 2]
# [1, 6, 5]
# [4, 7, 8]
# Step 4:
# [3, 6, 2]
# [1, 0, 5]
# [4, 7, 8]
# Step 5:
# [3, 6, 2]
# [1, 5, 0]
# [4, 7, 8]
# Step 6:
# [3, 6, 0]
# [1, 5, 2]
# [4, 7, 8]
# Step 7:
# [3, 0, 6]
# [1, 5, 2]
# [4, 7, 8]
# Step 8:
# [0, 3, 6]
# [1, 5, 2]
# [4, 7, 8]
# Step 9:
# [1, 3, 6]
# [0, 5, 2]
# [4, 7, 8]
# Step 10:
# [1, 3, 6]
# [4, 5, 2]
# [0, 7, 8]
# Step 11:
# [1, 3, 6]
# [4, 5, 2]
# [7, 0, 8]
# Step 12:
# [1, 3, 6]
# [4, 0, 2]
# [7, 5, 8]
# Step 13:
# [1, 3, 6]
# [4, 2, 0]
# [7, 5, 8]
# Step 14:
# [1, 3, 0]
# [4, 2, 6]
# [7, 5, 8]
# Step 15:
# [1, 0, 3]
# [4, 2, 6]
# [7, 5, 8]
# Step 16:
# [1, 2, 3]
# [4, 0, 6]
# [7, 5, 8]
# Step 17:
# [1, 2, 3]
# [4, 5, 6]
# [7, 0, 8]
# Step 18:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 0]

# %%
git remote add origin https://github.com/Vedant4857/AI-VEDANT-.git
git branch -M main
git push -u origin main
# Out:
#   File "/tmp/ipython-input-1-904627545.py", line 1
#     git remote add origin https://github.com/Vedant4857/AI-VEDANT-.git
#         ^
# SyntaxError: invalid syntax
